# %%
import pandas as pd
#read multiple tables
ds1 = pd.read_csv('Auto_Insurance_Claims_Sample.csv')
ds2 = pd.read_csv('CPI_2011.csv')
ds3 = pd.read_csv('GDP.csv')
ds4 = pd.read_csv('Total_Fatalities_2010-2011.csv')

# %%
#merge tables based on states
ds_1 = pd.merge(ds1, ds2, on = 'State')
ds_2 = pd.merge(ds_1, ds3, on = 'State')
ds = pd.merge(ds_2, ds4, on = 'State')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 32 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
#  12  Location Code                  9134 non-null   object
#  13  Marital Status                 9134 non-null   object
#  14  Monthly Premium Auto           9134 non-null   int64
#  15  Months Since Last Claim        9134 non-null   int64
#  16  Months Since Policy Inception  9134 non-null   int64
#  17  Number of Open Complaints      9134 non-null   int64
#  18  Number of Policies             9134 non-null   int64
#  19  Policy Type                    9134 non-null   object
#  20  Policy                         9134 non-null   object
#  21  Claim Reason                   9134 non-null   object
#  22  Sales Channel                  9134 non-null   object
#  23  Total Claim Amount             9134 non-null   float64
#  24  Vehicle Class                  9134 non-null   object
#  25  Vehicle Size                   9134 non-null   object
#  26  CPI                            9134 non-null   float64
#  27  GDP                            9134 non-null   int64
#  28  Total_Fatalities_2010          9134 non-null   int64
#  29  Total_Fatalities_2011          9134 non-null   int64
#  30  Total_Fatalities_Change        9134 non-null   int64
#  31  Total_Fatalities_% Change      9134 non-null   object
# dtypes: float64(3), int64(10), object(19)
# memory usage: 2.3+ MB

# %%
#drop unnecessary(duplicated) colums: Total_Fatalities_2010,Total_Fatalities_Change, and Total_Fatalities_% Change
ds = ds.drop(['Effective To Date', 'Total_Fatalities_2010', 'Total_Fatalities_Change', 'Total_Fatalities_% Change'], axis=1)

# %%
#create dummy variables for columns, such as 'State', 'Coverage', 'EmploymentStatus', 'Sales Channel'.....
dummy_ds = pd.get_dummies(ds[['State','Response','Coverage', 'Education','EmploymentStatus',
                              'Gender','Location Code', 'Marital Status', 'Policy Type',
                             'Policy','Claim Reason','Sales Channel','Vehicle Class','Vehicle Size']])
#concatenate the original dataframe and the dummy variables
ds = pd.concat([ds,dummy_ds], axis=1)
print(ds)
# Out:
#      Customer Country State Code   State  Claim Amount Response  Coverage  \
# 0     BU79786      US         KS  Kansas    276.351928       No     Basic
# 1     HB64268      US         KS  Kansas    281.369258       No     Basic
# 2     SV62436      US         KS  Kansas    304.179156       No  Extended
# 3     HO30839      US         KS  Kansas    534.691658       No  Extended
# 4     AO98601      US         KS  Kansas    501.888523       No     Basic
# ...       ...     ...        ...     ...           ...      ...       ...
# 9129  QL80621      US         IA    Iowa    224.987480       No     Basic
# 9130  LC47479      US         IA    Iowa   2862.231443       No  Extended
# 9131  VQ78876      US         IA    Iowa    466.039957       No     Basic
# 9132  JD86991      US         IA    Iowa    509.731866       No     Basic
# 9133  QM60216      US         IA    Iowa    890.699143       No  Extended
#
#      Education EmploymentStatus Gender  ...  Sales Channel_Web  \
# 0     Bachelor         Employed      F  ...                  0
# 1     Bachelor         Employed      M  ...                  0
# 2     Bachelor         Disabled      F  ...                  0
# 3       Master         Disabled      F  ...                  0
# 4     Bachelor         Employed      M  ...                  0
# ...        ...              ...    ...  ...                ...
# 9129  Bachelor       Unemployed      F  ...                  1
# 9130   College         Employed      M  ...                  0
# 9131  Bachelor         Employed      F  ...                  0
# 9132  Bachelor         Employed      M  ...                  0
# 9133   College         Employed      M  ...                  0
#
#      Vehicle Class_Four-Door Car Vehicle Class_Luxury Car  \
# 0                              0                        0
# 1                              1                        0
# 2                              1                        0
# 3                              0                        0
# 4                              0                        0
# ...                          ...                      ...
# 9129                           1                        0
# 9130                           0                        1
# 9131                           0                        0
# 9132                           0                        0
# 9133                           0                        1
#
#       Vehicle Class_Luxury SUV  Vehicle Class_SUV  Vehicle Class_Sports Car  \
# 0                            0                  0                         0
# 1                            0                  0                         0
# 2                            0                  0                         0
# 3                            0                  1                         0
# 4                            0                  0                         0
# ...                        ...                ...                       ...
# 9129                         0                  0                         0
# 9130                         0                  0                         0
# 9131                         0                  1                         0
# 9132                         0                  0                         0
# 9133                         0                  0                         0
#
#       Vehicle Class_Two-Door Car  Vehicle Size_Large Vehicle Size_Medsize  \
# 0                              1                   0                    1
# 1                              0                   0                    1
# 2                              0                   0                    1
# 3                              0                   0                    1
# 4                              1                   0                    0
# ...                          ...                 ...                  ...
# 9129                           0                   0                    1
# 9130                           0                   0                    0
# 9131                           0                   0                    1
# 9132                           1                   0                    1
# 9133                           0                   0                    1
#
#      Vehicle Size_Small
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 9129                  0
# 9130                  1
# 9131                  0
# 9132                  0
# 9133                  0
#
# [9134 rows x 85 columns]

# %%
ds.info()
# drop duplicated colums, ones that get dummy variables
ds = ds.drop(['State','Response','Coverage', 'Education','EmploymentStatus',
                              'Gender','Location Code', 'Marital Status', 'Policy Type',
                             'Policy','Claim Reason','Sales Channel','Vehicle Class','Vehicle Size'], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 85 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer                        9134 non-null   object
#  1   Country                         9134 non-null   object
#  2   State Code                      9134 non-null   object
#  3   State                           9134 non-null   object
#  4   Claim Amount                    9134 non-null   float64
#  5   Response                        9134 non-null   object
#  6   Coverage                        9134 non-null   object
#  7   Education                       9134 non-null   object
#  8   EmploymentStatus                9134 non-null   object
#  9   Gender                          9134 non-null   object
#  10  Income                          9134 non-null   int64
#  11  Location Code                   9134 non-null   object
#  12  Marital Status                  9134 non-null   object
#  13  Monthly Premium Auto            9134 non-null   int64
#  14  Months Since Last Claim         9134 non-null   int64
#  15  Months Since Policy Inception   9134 non-null   int64
#  16  Number of Open Complaints       9134 non-null   int64
#  17  Number of Policies              9134 non-null   int64
#  18  Policy Type                     9134 non-null   object
#  19  Policy                          9134 non-null   object
#  20  Claim Reason                    9134 non-null   object
#  21  Sales Channel                   9134 non-null   object
#  22  Total Claim Amount              9134 non-null   float64
#  23  Vehicle Class                   9134 non-null   object
#  24  Vehicle Size                    9134 non-null   object
#  25  CPI                             9134 non-null   float64
#  26  GDP                             9134 non-null   int64
#  27  Total_Fatalities_2011           9134 non-null   int64
#  28  State_Iowa                      9134 non-null   uint8
#  29  State_Kansas                    9134 non-null   uint8
#  30  State_Missouri                  9134 non-null   uint8
#  31  State_Nebraska                  9134 non-null   uint8
#  32  State_Oklahoma                  9134 non-null   uint8
#  33  Response_No                     9134 non-null   uint8
#  34  Response_Yes                    9134 non-null   uint8
#  35  Coverage_Basic                  9134 non-null   uint8
#  36  Coverage_Extended               9134 non-null   uint8
#  37  Coverage_Premium                9134 non-null   uint8
#  38  Education_Bachelor              9134 non-null   uint8
#  39  Education_College               9134 non-null   uint8
#  40  Education_Doctor                9134 non-null   uint8
#  41  Education_High School or Below  9134 non-null   uint8
#  42  Education_Master                9134 non-null   uint8
#  43  EmploymentStatus_Disabled       9134 non-null   uint8
#  44  EmploymentStatus_Employed       9134 non-null   uint8
#  45  EmploymentStatus_Medical Leave  9134 non-null   uint8
#  46  EmploymentStatus_Retired        9134 non-null   uint8
#  47  EmploymentStatus_Unemployed     9134 non-null   uint8
#  48  Gender_F                        9134 non-null   uint8
#  49  Gender_M                        9134 non-null   uint8
#  50  Location Code_Rural             9134 non-null   uint8
#  51  Location Code_Suburban          9134 non-null   uint8
#  52  Location Code_Urban             9134 non-null   uint8
#  53  Marital Status_Divorced         9134 non-null   uint8
#  54  Marital Status_Married          9134 non-null   uint8
#  55  Marital Status_Single           9134 non-null   uint8
#  56  Policy Type_Corporate Auto      9134 non-null   uint8
#  57  Policy Type_Personal Auto       9134 non-null   uint8
#  58  Policy Type_Special Auto        9134 non-null   uint8
#  59  Policy_Corporate L1             9134 non-null   uint8
#  60  Policy_Corporate L2             9134 non-null   uint8
#  61  Policy_Corporate L3             9134 non-null   uint8
#  62  Policy_Personal L1              9134 non-null   uint8
#  63  Policy_Personal L2              9134 non-null   uint8
#  64  Policy_Personal L3              9134 non-null   uint8
#  65  Policy_Special L1               9134 non-null   uint8
#  66  Policy_Special L2               9134 non-null   uint8
#  67  Policy_Special L3               9134 non-null   uint8
#  68  Claim Reason_Collision          9134 non-null   uint8
#  69  Claim Reason_Hail               9134 non-null   uint8
#  70  Claim Reason_Other              9134 non-null   uint8
#  71  Claim Reason_Scratch/Dent       9134 non-null   uint8
#  72  Sales Channel_Agent             9134 non-null   uint8
#  73  Sales Channel_Branch            9134 non-null   uint8
#  74  Sales Channel_Call Center       9134 non-null   uint8
#  75  Sales Channel_Web               9134 non-null   uint8
#  76  Vehicle Class_Four-Door Car     9134 non-null   uint8
#  77  Vehicle Class_Luxury Car        9134 non-null   uint8
#  78  Vehicle Class_Luxury SUV        9134 non-null   uint8
#  79  Vehicle Class_SUV               9134 non-null   uint8
#  80  Vehicle Class_Sports Car        9134 non-null   uint8
#  81  Vehicle Class_Two-Door Car      9134 non-null   uint8
#  82  Vehicle Size_Large              9134 non-null   uint8
#  83  Vehicle Size_Medsize            9134 non-null   uint8
#  84  Vehicle Size_Small              9134 non-null   uint8
# dtypes: float64(3), int64(8), object(17), uint8(57)
# memory usage: 2.5+ MB

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 9133
# Data columns (total 71 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer                        9134 non-null   object
#  1   Country                         9134 non-null   object
#  2   State Code                      9134 non-null   object
#  3   Claim Amount                    9134 non-null   float64
#  4   Income                          9134 non-null   int64
#  5   Monthly Premium Auto            9134 non-null   int64
#  6   Months Since Last Claim         9134 non-null   int64
#  7   Months Since Policy Inception   9134 non-null   int64
#  8   Number of Open Complaints       9134 non-null   int64
#  9   Number of Policies              9134 non-null   int64
#  10  Total Claim Amount              9134 non-null   float64
#  11  CPI                             9134 non-null   float64
#  12  GDP                             9134 non-null   int64
#  13  Total_Fatalities_2011           9134 non-null   int64
#  14  State_Iowa                      9134 non-null   uint8
#  15  State_Kansas                    9134 non-null   uint8
#  16  State_Missouri                  9134 non-null   uint8
#  17  State_Nebraska                  9134 non-null   uint8
#  18  State_Oklahoma                  9134 non-null   uint8
#  19  Response_No                     9134 non-null   uint8
#  20  Response_Yes                    9134 non-null   uint8
#  21  Coverage_Basic                  9134 non-null   uint8
#  22  Coverage_Extended               9134 non-null   uint8
#  23  Coverage_Premium                9134 non-null   uint8
#  24  Education_Bachelor              9134 non-null   uint8
#  25  Education_College               9134 non-null   uint8
#  26  Education_Doctor                9134 non-null   uint8
#  27  Education_High School or Below  9134 non-null   uint8
#  28  Education_Master                9134 non-null   uint8
#  29  EmploymentStatus_Disabled       9134 non-null   uint8
#  30  EmploymentStatus_Employed       9134 non-null   uint8
#  31  EmploymentStatus_Medical Leave  9134 non-null   uint8
#  32  EmploymentStatus_Retired        9134 non-null   uint8
#  33  EmploymentStatus_Unemployed     9134 non-null   uint8
#  34  Gender_F                        9134 non-null   uint8
#  35  Gender_M                        9134 non-null   uint8
#  36  Location Code_Rural             9134 non-null   uint8
#  37  Location Code_Suburban          9134 non-null   uint8
#  38  Location Code_Urban             9134 non-null   uint8
#  39  Marital Status_Divorced         9134 non-null   uint8
#  40  Marital Status_Married          9134 non-null   uint8
#  41  Marital Status_Single           9134 non-null   uint8
#  42  Policy Type_Corporate Auto      9134 non-null   uint8
#  43  Policy Type_Personal Auto       9134 non-null   uint8
#  44  Policy Type_Special Auto        9134 non-null   uint8
#  45  Policy_Corporate L1             9134 non-null   uint8
#  46  Policy_Corporate L2             9134 non-null   uint8
#  47  Policy_Corporate L3             9134 non-null   uint8
#  48  Policy_Personal L1              9134 non-null   uint8
#  49  Policy_Personal L2              9134 non-null   uint8
#  50  Policy_Personal L3              9134 non-null   uint8
#  51  Policy_Special L1               9134 non-null   uint8
#  52  Policy_Special L2               9134 non-null   uint8
#  53  Policy_Special L3               9134 non-null   uint8
#  54  Claim Reason_Collision          9134 non-null   uint8
#  55  Claim Reason_Hail               9134 non-null   uint8
#  56  Claim Reason_Other              9134 non-null   uint8
#  57  Claim Reason_Scratch/Dent       9134 non-null   uint8
#  58  Sales Channel_Agent             9134 non-null   uint8
#  59  Sales Channel_Branch            9134 non-null   uint8
#  60  Sales Channel_Call Center       9134 non-null   uint8
#  61  Sales Channel_Web               9134 non-null   uint8
#  62  Vehicle Class_Four-Door Car     9134 non-null   uint8
#  63  Vehicle Class_Luxury Car        9134 non-null   uint8
#  64  Vehicle Class_Luxury SUV        9134 non-null   uint8
#  65  Vehicle Class_SUV               9134 non-null   uint8
#  66  Vehicle Class_Sports Car        9134 non-null   uint8
#  67  Vehicle Class_Two-Door Car      9134 non-null   uint8
#  68  Vehicle Size_Large              9134 non-null   uint8
#  69  Vehicle Size_Medsize            9134 non-null   uint8
#  70  Vehicle Size_Small              9134 non-null   uint8
# dtypes: float64(3), int64(8), object(3), uint8(57)
# memory usage: 1.5+ MB

# %%
ds.to_csv('newdata.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np

#State_Iowa = ds.loc(ds['State_Iowa']==1,'Claim Amount').values
#State_Kansas = ds.loc(ds['State_Kansas']==1,'Claim Amount').values
#State_Missouri = ds.loc(ds['State_Missouri']==1,'Claim Amount').values
#State_Nebraska = ds.loc(ds['State_Nebraska']==1,'Claim Amount').values
#State_Oklahoma = ds.loc(ds['State_Oklahoma']==1,'Claim Amount').values

#plt.boxplot([State_Iowa, State_Kansas, State_Missouri, State_Nebraska, State_Oklahoma],
#            labels=['Iowa', 'Kansas', 'Missouri', 'Nebraska', 'Oklahoma'])

#not working
#dsa = ['Claim Amount','State_Iowa', 'State_Kansas', 'State_Missouri', 'State_Nebraska', 'State_Oklahoma']
#bp =[]
#for d in dsa:
#    i=ds[d].values
#    bp.append(i)
#ds1,ds2,ds3,ds4,ds5,ds6 = bp
#plt.boxplot([ds1,ds2,ds3,ds4,ds5,ds6], labels=dsa)
#plt.figure(figsize=(20,15))
#plt.boxplot([ds1,ds2,ds3,ds4,ds5,ds6], labels=dsa)
#plt.semilogy()

grouped_data = ds[['State','Claim Amount']].groupby('State')
states = []
claims = []
for state, group in grouped_data:
    states.append(state)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to states
plt.xticks(range(1, len(states) + 1), states)

# set y-axis label
plt.ylabel('Claim Amount')

# display the plot
plt.show()

# %%
grouped_data = ds[['State','Claim Amount']].groupby('State')
states = []
claims = []
for state, group in grouped_data:
    states.append(state)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)
plt.xticks(range(1, len(states) + 1), states)
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
plt.show()

# %%
#boxplot: Claim Amount v.s. Response
grouped_data_R = ds[['Response','Claim Amount']].groupby('Response')
responses = []
claims = []
for response, group in grouped_data_R:
    responses.append(response)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to response
plt.xticks(range(1, len(responses) + 1), responses)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Coverage
grouped_data_R = ds[['Coverage','Claim Amount']].groupby('Coverage')
coverages = []
claims = []
for coverage, group in grouped_data_R:
    coverages.append(coverage)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to coverages
plt.xticks(range(1, len(coverages) + 1), coverages)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Gender
grouped_data_R = ds[['Gender','Claim Amount']].groupby('Gender')
genders = []
claims = []
for gender, group in grouped_data_R:
    genders.append(gender)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to gender
plt.xticks(range(1, len(genders) + 1), genders)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Marital Status
grouped_data_R = ds[['Marital Status','Claim Amount']].groupby('Marital Status')
Mstatus = []
claims = []
for status, group in grouped_data_R:
    Mstatus.append(status)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to Marital Status
plt.xticks(range(1, len(Mstatus) + 1), Mstatus)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Policy Type
grouped_data_R = ds[['Policy Type','Claim Amount']].groupby('Policy Type')
policies = []
claims = []
for policy, group in grouped_data_R:
    policies.append(policy)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to policies
plt.xticks(range(1, len(policies) + 1), policies)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Claim Reason
grouped_data_R = ds[['Claim Reason','Claim Amount']].groupby('Claim Reason')
reasons = []
claims = []
for reason, group in grouped_data_R:
    reasons.append(reason)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to reasons
plt.xticks(range(1, len(reasons) + 1), reasons)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Vehicle Class
grouped_data_R = ds[['Vehicle Class','Claim Amount']].groupby('Vehicle Class')
classes = []
claims = []
for clas, group in grouped_data_R:
    classes.append(clas)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to classes
plt.xticks(range(1, len(classes) + 1), classes)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()

# %%
#boxplot:Claim Amount v.s. Vehicle Size
grouped_data_R = ds[['Vehicle Size','Claim Amount']].groupby('Vehicle Size')
sizes = []
claims = []
for size, group in grouped_data_R:
    sizes.append(size)
    claims.append(group['Claim Amount'].tolist())
    
plt.boxplot(claims)

# set x-axis labels to sizes
plt.xticks(range(1, len(sizes) + 1), sizes)

# set y-axis label
plt.ylabel('Claim Amount')
#scale
plt.yscale('log')
# display the plot
plt.show()
